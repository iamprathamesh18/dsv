#  54 35 30 65 67 38 34 47 49 31 57 51 61 55 61 49 48 36 50 46 59 61 69 69
#  66 55 48 67 53 41 46 61 56 37 64 61 51 36 56 46 50 60 58 46 62 45 32 34
#  41 40 45 41 44 54 63 30 65 31 31 54 55 49 32 39 32 32 47 66 31 39 33 50
#  69 60 39 51 48 68 55 41 64 41 42 40 32 54 33 54 49 58 59 65 64 46 46 55
#  31 48 59 52 33 67 58 44 57 58 49 62 43 60 33 30 52 64 57 68 62 59 42 45
#  57 67 56 58 58 42 34 46 48 57 69 33 32 43 36 45 59 58 46 54 63 40 43 58
#  33 65 52 32 56 30 61 52 54 30 33 58 52 58 39 32 39 30 54 37 60 64 40 69
#  53 33 39 58 50 59 61 68 42 58 48 41 32 62 60 39 55 51 57 45 57 65 43 56
#  59 69 38 50 51 57 51 63 67 43 39 36 43 42 52 69]

# %%
import statistics

# %%
mean=statistics.mean(test)
print("mean:",mean)
# Out:
# mean: 49

# %%
variance=statistics.variance(test)
print("variance:",variance)
# Out:
# variance: 132

# %%
median=statistics.median(test)
print("median:",median)
# Out:
# median: 50.0

# %%
mode=statistics.mode(test)
print("mode:", mode)
# Out:
# mode: 52

# %%
Standard_Deviation=np.std(test)
print("standard_deviation",Standard_Deviation)
# Out:
# standard_deviation 11.4895482504753

# %% [markdown]
# ### Implemantation of normal distribution

# %%
size=10000
values=np.random.normal(mean,Standard_Deviation,size)

# %%
plt.hist(values,100)
# plotting mean
plt.axvline(values.mean(),color='b',linestyle="--",linewidth=2)
plt.show()

# %% [markdown]
# ## Central Limit Therom

# %%
roll=randint(1,6,100)
print(roll)
# Out:
# [2 5 5 3 3 2 1 2 5 1 3 2 2 5 2 1 1 3 5 2 4 3 5 3 2 3 4 2 2 4 4 2 5 4 5 4 3
#  2 2 1 2 4 1 5 5 5 4 2 1 1 5 3 5 1 1 2 5 3 5 4 3 5 2 3 5 5 1 3 5 3 2 3 5 1
#  1 5 3 4 5 2 3 1 4 1 3 1 3 1 3 3 2 5 4 1 4 5 5 5 3 2]

# %%
from numpy import mean
means=[mean(randint(1,6,100)) for _ in range(1000)]
plt.hist(means)
plt.show()

# %%
mean(means)
# Out:
# 2.9937600000000004

# %%
import seaborn as sns
sns.displot(data=means, kind="kde")

# %%
data=randint(1,6,1000000)
data
statistics.mean(data)
# Out:
# 3

# %% [markdown]
# As per the central Limit Therom mean of smaple means should be equal to population mean and sample means should follow standard normal distribution when plotted.
# So here our population mean(3)is near about mean of sample means(2.9995) and sample means follows standard uniform distribution hence Central Limit therom is implemented

# %% [markdown]
# ### Correlation

# %%
import sklearn

# %%
np.random.seed(100)

#create array of 50 random integers between 0 and 10
x = np.random.randint(0, 10, 50)

np.corrcoef(x,x)
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
#create a positively correlated array with some random noise
y = x + np.random.randint(10, 20, 50)

#calculate the correlation between the two arrays
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.75618923],
#        [0.75618923, 1.        ]])

# %%
# plotting the data
plt.scatter(x, y)

# %%
ax = sns.heatmap(np.corrcoef(x,y), annot=True)

# %%
# !jupyter nbconvert --to html /content/DSV_Exp9_XOR_Gate.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/DSV_Exp8_Decision_Tree.ipynb to html
# [NbConvertApp] Writing 761991 bytes to /content/DSV_Exp8_Decision_Tree.html

# %%
from google.colab import files
files.download('/content/DSV_Exp9_XOR_Gate.html')
